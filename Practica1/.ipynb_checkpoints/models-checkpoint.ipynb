# %% [markdown]
# # Classificació de l'idioma d'una paraula
# Autors:
# - Jonathan Salisbury Vega
# - Julià Wallis Medina
#
# Aquesta pràctica consisteix en la classificació de l'idioma d'una paraula emprant SVMs. Per a això, s'ha creat un dataset de paraules en diferents idiomes, i s'han extret diferentes característiques de les paraules. Després s'ha entrenat un model de classificació per tal de poder classificar les paraules en els seus idiomes corresponents.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read Preprocessed Data

# %%
df = pd.read_csv('data/final.csv', index_col=0)
df.head()
# Out:
#    word  lang  len  vow  acc  accl  accr  die  cir  ñ  ...  en_zipf  es_zipf  \
# 0    as     1    2    1    0     0     0    0    0  0  ...     6.77     4.66
# 1   his     1    3    1    0     0     0    0    0  0  ...     6.51     3.63
# 2  that     1    4    1    0     0     0    0    0  0  ...     7.01     4.12
# 3    he     1    2    1    0     0     0    0    0  0  ...     6.69     5.77
# 4   was     1    3    1    0     0     0    0    0  0  ...     6.82     3.84
#
#    ca_zipf  it_zipf  fr_zipf  pt_zipf  de_zipf  sv_zipf  pl_zipf  ru_zipf
# 0     4.22     4.26     5.79     6.73     4.57     4.66     4.51     3.89
# 1     3.12     3.67     3.70     3.94     3.93     3.89     3.82     3.62
# 2     3.67     4.24     4.12     4.38     4.56     4.50     4.40     3.98
# 3     5.87     4.00     4.02     4.01     4.36     4.32     4.39     3.74
# 4     3.78     3.94     3.83     3.99     6.49     4.01     5.57     3.76
#
# [5 rows x 66 columns]

# %%
# Check feature correlations with language
df.corr(numeric_only=True).round(2)['lang'].sort_values(ascending=False)
# Out:
# lang       1.00
# rus        0.37
# sue        0.22
# suf_rus    0.19
# pre_rus    0.16
#            ...
# es_zipf   -0.32
# fr_zipf   -0.34
# ca_zipf   -0.38
# en_zipf   -0.41
# de_zipf   -0.55
# Name: lang, Length: 65, dtype: float64

# %% [markdown]
# ### Data preparation for models

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Separate features from target
X = df.drop(['word', 'lang'], axis=1)
y = df['lang']

# %%
# Split data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=43)

# %%
# Scale Data: https://towardsdatascience.com/feature-scaling-and-normalisation-in-a-nutshell-5319af86f89b
scaler = StandardScaler() # try different scalers
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Dimensionality Reduction: https://www.mikulskibartosz.name/pca-how-to-choose-the-number-of-components/
pca = PCA(n_components=0.99, random_state=43) # try different n_components
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %% [markdown]
# ### Models

# %%
from sklearn import svm

# %%
# Create common Models with different Kernels
models = [
    svm.SVC(kernel='linear', probability=True),  # linear kernel
    svm.SVC(kernel='poly', probability=True),  # polynomial kernel with degree 3
    svm.SVC(kernel='rbf', probability=True),  # RBF kernel with gamma = 0.1
    svm.SVC(kernel='sigmoid', probability=True)
]

# Train models
for model in models:
    model.fit(X_train_pca, y_train)

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import top_k_accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# Accuracy

# %%
for i, model in enumerate(models):
    score = model.score(X_test_pca, y_test)
    print(f'Model {i+1} accuracy: {score * 100}%')
# Out:
# Model 1 accuracy: 82.43927125506073%
# Model 2 accuracy: 73.48178137651821%
# Model 3 accuracy: 81.2246963562753%
# Model 4 accuracy: 76.01214574898786%

# %% [markdown]
# Top 3 Accuracy

# %%
for i, model in enumerate(models):
    prediction = model.predict_proba(X_test_pca)
    print(f'Top 3 accuracy model {i+1}: {top_k_accuracy_score(y_test, prediction, k=3)*100}%')
# Out:
# Top 3 accuracy model 1: 96.71052631578947%
# Top 3 accuracy model 2: 94.12955465587044%
# Top 3 accuracy model 3: 96.45748987854252%
# Top 3 accuracy model 4: 93.57287449392713%

# %% [markdown]
# Classification Reports

# %%
# Generate classification reports for the models
langs = ['en', 'ca', 'es', 'de', 'fr', 'pl', 'pt', 'ru', 'it', 'sv']
fig, ax = plt.subplots(1, len(models), figsize=(20, 5))
for i, model in enumerate(models):
    clf_report = classification_report(y_test, model.predict(X_test_pca), zero_division=0, target_names=langs, output_dict=True)
    sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True, ax=ax[i])
    ax[i].set_title(f'Model {i+1}')
plt.show()

# %% [markdown]
# Confusion Matrices

# %%
# Generate confusion matrices for the models and plot them as heatmaps try to make them look pretty,you can use seaborn for this
fig, ax = plt.subplots(1, len(models), figsize=(20, 4))
for i, model in enumerate(models):
    cm = confusion_matrix(y_test, model.predict(X_test_pca))
    sns.heatmap(cm, annot=True, ax=ax[i], fmt='d', xticklabels=langs, yticklabels=langs)
    ax[i].set_title(f'Model {i+1}')
plt.show()

# %% [markdown]
# ### Grid Search
# Lets try to find the best hiperparameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Let's preform a grid search on the model1 (SVM) to find the best parameters

parameters = {'C': [0.1, 1, 5, 10], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['linear', 'rbf'], "decision_function_shape": ["ovo", "ovr"]} # AÑADIR SIGMOID???

grid = GridSearchCV(svm.SVC(), parameters, refit=True, verbose=3)
grid.fit(X_train_pca, y_train)

print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.824 total time=   0.3s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.825 total time=   0.3s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.816 total time=   0.3s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.815 total time=   0.3s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.819 total time=   0.3s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.204 total time=   2.6s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.202 total time=   2.5s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.208 total time=   2.5s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.196 total time=   2.5s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.199 total time=   2.5s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.824 total time=   0.2s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.816 total time=   0.2s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.815 total time=   0.2s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.819 total time=   0.2s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.552 total time=   2.0s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.550 total time=   2.0s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.526 total time=   2.0s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.537 total time=   2.0s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.559 total time=   2.0s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.824 total time=   0.2s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.816 total time=   0.2s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.815 total time=   0.2s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.819 total time=   0.2s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.776 total time=   1.4s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.765 total time=   1.4s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.754 total time=   1.4s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.772 total time=   1.4s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.768 total time=   1.4s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.824 total time=   0.2s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.816 total time=   0.2s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.815 total time=   0.2s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.819 total time=   0.2s
# [CV 1/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.644 total time=   2.1s
# [CV 2/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.622 total time=   2.1s
# [CV 3/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.632 total time=   2.1s
# [CV 4/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.635 total time=   2.1s
# [CV 5/5] END C=0.1, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.644 total time=   2.1s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.824 total time=   0.2s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.816 total time=   0.2s
# [CV 4/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.815 total time=   0.2s
# [CV 5/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.819 total time=   0.2s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.204 total time=   2.6s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.202 total time=   2.5s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.208 total time=   2.5s
# [CV 4/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.196 total time=   2.4s
# [CV 5/5] END C=0.1, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.199 total time=   2.5s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.824 total time=   0.2s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.816 total time=   0.2s
# [CV 4/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.815 total time=   0.2s
# [CV 5/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.819 total time=   0.2s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.552 total time=   2.1s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.550 total time=   2.0s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.526 total time=   2.0s
# [CV 4/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.537 total time=   2.0s
# [CV 5/5] END C=0.1, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.559 total time=   2.0s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.824 total time=   0.3s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.816 total time=   0.2s
# [CV 4/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.815 total time=   0.2s
# [CV 5/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.819 total time=   0.2s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.776 total time=   1.4s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.765 total time=   1.4s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.754 total time=   1.4s
# [CV 4/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.772 total time=   1.4s
# [CV 5/5] END C=0.1, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.768 total time=   1.4s
# [CV 1/5] END C=0.1, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.824 total time=   0.2s
# [CV 2/5] END C=0.1, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.825 total time=   0.2s
# [CV 3/5] END C=0.1, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0

# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=linear;, score=0.811 total time=   1.5s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.486 total time=   2.6s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.468 total time=   2.7s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.459 total time=   2.6s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.475 total time=   2.8s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=1, kernel=rbf;, score=0.461 total time=   2.7s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.827 total time=   1.6s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.806 total time=   1.7s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.813 total time=   1.6s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=linear;, score=0.811 total time=   1.5s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.738 total time=   2.1s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.715 total time=   2.0s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.707 total time=   2.0s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.729 total time=   1.9s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=0.1, kernel=rbf;, score=0.728 total time=   2.0s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.827 total time=   1.6s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.806 total time=   1.7s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.813 total time=   1.5s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=linear;, score=0.811 total time=   1.4s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.806 total time=   0.6s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.799 total time=   0.6s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.796 total time=   0.6s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.806 total time=   0.6s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=0.01, kernel=rbf;, score=0.804 total time=   0.6s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.827 total time=   1.7s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.806 total time=   1.8s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.813 total time=   1.7s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.813 total time=   1.4s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=0.811 total time=   1.5s
# [CV 1/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.6s
# [CV 2/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.6s
# [CV 3/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.826 total time=   0.6s
# [CV 4/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.813 total time=   0.6s
# [CV 5/5] END C=10, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=0.824 total time=   0.6s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.827 total time=   1.7s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.806 total time=   1.7s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.813 total time=   1.6s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=linear;, score=0.811 total time=   1.5s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.486 total time=   2.7s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.468 total time=   2.7s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.459 total time=   2.6s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.475 total time=   2.7s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=0.461 total time=   2.6s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.827 total time=   1.6s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.806 total time=   1.8s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.813 total time=   1.5s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=linear;, score=0.811 total time=   1.5s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.738 total time=   2.0s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.715 total time=   2.0s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.707 total time=   1.9s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.729 total time=   2.0s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=0.728 total time=   2.0s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.827 total time=   1.6s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.806 total time=   1.7s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.813 total time=   1.6s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=linear;, score=0.811 total time=   1.5s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.806 total time=   0.6s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.799 total time=   0.6s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.796 total time=   0.7s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.806 total time=   0.6s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=0.804 total time=   0.7s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.827 total time=   1.8s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.806 total time=   1.7s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.813 total time=   1.5s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.813 total time=   1.3s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=linear;, score=0.811 total time=   1.6s
# [CV 1/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.6s
# [CV 2/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.6s
# [CV 3/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=0.826 total time=   0.6s
# [CV 4/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=0.813 total time=   0.6s
# [CV 5/5] END C=10, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=0.824 total time=   0.6s
# {'C': 5, 'decision_function_shape': 'ovo', 'gamma': 0.001, 'kernel': 'rbf'}

# %% [markdown]
# Create new Model with the best hyperparameters

# %%
# Create and train model

#model = svm.SVC(C=5, kernel='rbf', gamma=0.001, decision_function_shape="ovo", probability=True)
model = grid.best_estimator_

# Accuracy
score = model.score(X_test_pca, y_test)
print(f'Model {i+1} accuracy: {score * 100}%')

# Top 3
"""
prediction = model.predict_proba(X_test_pca)
print(f'Top 3 accuracy model {i+1}: {top_k_accuracy_score(y_test, prediction, k=3)*100}%')
"""

# Classification Report
clf_report = classification_report(y_test, model.predict(X_test_pca), zero_division=0, target_names=langs, output_dict=True)
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True).set(title="Classification Report")
plt.show()

# Confussion Matrix
cm = confusion_matrix(y_test, model.predict(X_test_pca))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=langs, yticklabels=langs).set(title="Confussion Matrix")
plt.show()
# Out:
# Model 4 accuracy: 83.09716599190283%
